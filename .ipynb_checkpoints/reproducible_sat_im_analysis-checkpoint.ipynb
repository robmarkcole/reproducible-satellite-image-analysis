# %%
import rasterio

# %%
rasterio.__version__
# Out:
# '1.0.8'

# %%
# !conda list
# Out:
# # packages in environment at /Users/robincole/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py36h2fc01ae_0
# absl-py                   0.3.0                     <pip>
# adafruit-ampy             1.0.5                     <pip>
# adal                      1.2.0                     <pip>
# affine                    2.2.1                     <pip>
# airflow                   1.8.0                     <pip>
# alabaster                 0.7.10           py36h174008c_0
# alembic                   0.8.10                    <pip>
# anaconda                  5.2.0                    py36_3
# anaconda-client           1.6.14                   py36_0
# anaconda-navigator        1.8.7                    py36_0
# anaconda-project          0.8.2            py36h9ee5d53_0
# ansiwrap                  0.8.3                     <pip>
# apache-airflow            1.10.0                    <pip>
# ...

# %% [markdown]
# Clearly still in base env..
